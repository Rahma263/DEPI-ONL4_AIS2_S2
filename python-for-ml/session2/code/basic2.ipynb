# %%
list_one=[1,2,3,1,"depi","learning",True,[1,2,3,"True",["ml","dl","cv","nlp"]]]

# %%
list_one[7][4][0]="DS"
list_one
# Out:
# [1,
#  2,
#  3,
#  1,
#  'depi',
#  'learning',
#  True,
#  [1, 2, 3, 'True', ['DS', 'dl', 'cv', 'nlp']]]

# %%
list_1=["depi","learning","ml"]
list_1.append("dl")
list_1
# Out:
# ['depi', 'learning', 'ml', 'dl']

# %%
list_1.insert(0,"data")
list_1
# Out:
# ['data', 'data', 'depi', 'learning', 'ml', 'dl']

# %%
list_2=[1,2,3]
list_3=[4,5,6]
list_2+list_3
list_2.extend(list_3)
list_2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_new=["depi","learning","python"]
list_new.remove("depi")

# %%
list_new
# Out:
# ['learning', 'python']

# %%
list_new.pop(0)
# Out:
# 'learning'

# %%
list_new=["depi","learning","python"]
list_new.remove("depi")

# %%
del list_new[0]

# %%
list_new
# Out:
# ['learning', 'python']

# %%
lst_1=[1,2,3]
lst_2=[4,5,6]
lst_3=[7,6,8]
matrix=[lst_1,lst_2,lst_3]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 6, 8]]

# %%
my_list=['one','two','three',4.6]
my_list*2
# Out:
# ['one', 'two', 'three', 4.6, 'one', 'two', 'three', 4.6]

# %%
name=input("enter your name:")
type(name)
# Out:
# str

# %%
name=input("enter your name:")
id=input("enter your id")
print(f"your name is {name}, your id is {id}")
# Out:
# your name is rahma, your id is 2005

# %%
input_list=["depi","learning","python"]
item=input("enter item in the list")
input_list.remove(item)
print(f"output list={input_list}")
# Out:
# output list=['learning', 'python']

# %%
my_list=[1,2,3,3]
index_val=my_list.count(3)
index_val
# Out:
# 2

# %%
list_sort=[3,1,5,7,9,2,0]
list_sort.clear()
list_sort
# Out:
# []

# %%
name="depi"
tuple(name)
# Out:
# ('d', 'e', 'p', 'i')

# %%
set_1={"depi","learning"}
set_1
# Out:
# {'depi', 'learning'}

# %%
color={"red","green","blue"}
color.remove("green")
print(color)
# Out:
# {'red', 'blue'}

# %%
color={"red","green","blue"}
color.discard("blue")
print(color)
# Out:
# {'red', 'green'}

# %%
a={1,2,3}
b={3,4,5}
print(a.difference(b))
# Out:
# {1, 2}

# %%
dict_1={"key_1":25}
dict_1["key_1"]="depi"

# %%
dict_1
# Out:
# {'key_1': 'depi'}

# %%
num1=float(input("enter first number:"))
num2=float(input("enter second number:"))
addition=num1+num2
substraction=num1-num2
multiplication=num1*num2
division=num1/num2
print(f"the addition of the  {num1} and {num2} is {addition} and substaraction is{substraction}")
print(f"the multiplication of the  {num1} and {num2} is {multiplication} and division is{division}")
# Out:
# the addition of the  20.0 and 5.0 is 25.0 and substaraction is15.0
# the multiplication of the  20.0 and 5.0 is 100.0 and division is4.0

# %%
a=200
b=33
if b > a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x=5
y=10
if x>0 and y>0:
    print("positive number")
# Out:
# positive number

# %%
x=5
result= "even" if x%2==0 else "odd"
print(result)
# Out:
# odd

# %%
a=10
b=5
result= a+b if a>b else a-b
print (result)
# Out:
# 15

# %%
age=21
print("adult") if age>=18 else print("teenager") if age>=13 else print("child")
# Out:
# adult

# %%
is_sunny=True
tem=25
if is_sunny:
    print("sunny day")
    if tem>20:
        print("warm")
    else:
        print("cool")
else:
    print("not sunny day")
# Out:
# sunny day
# warm

# %%
grade= int(input("enter your grade:"))
if 0<=grade<=100:
    if 90<=grade<=100:
        print("A")
    elif 90<=grade<=80:
        print("B")
    elif 80<=grade<=70:
        print("C")
    elif 70<=grade<=60:
        print("D")
    else:
        print("F")
else:
    print("enter value between 0 to 100")
# Out:
# A

# %%
for i in range(6):
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range(6):
    if i==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(6):
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
if x>30:
    pass

# %%
x=6
while x>0:
    print("python")
    x-=1
# Out:
# python
# python
# python
# python
# python
# python
