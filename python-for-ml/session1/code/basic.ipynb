# %%
name="rahma"
age=20
print("my name is {}and my age is {}".format(name,age))
# Out:
# my name is rahmaand my age is 20

# %%
your_name="rahma"
your_age=20
course_name="AI and data science"
print(f"my name is {your_name} and my age is {your_age} and i am engaged in learning {course_name}")
# Out:
# my name is rahma and my age is 20 and i am engaged in learning AI and data science

# %%
x ="DEPI"
x[0]
# Out:
# 'D'

# %%
name="depi learning"
upper_text=name.upper()
print(upper_text)
# Out:
# DEPI LEARNING

# %%
lower_text=name.lower()
lower_text
# Out:
# 'depi learning'

# %%
name.replace("depi","depi_ml")
# Out:
# 'depi_ml learning'

# %%
name="depi learning for machine learning depi"
# name.count("depi")
print(type(name))
x=name.split()
print(type(x))
response=' '.join(x)
response
print(type(response))
response.startswith()
# Out:
# <class 'str'>
# <class 'list'>

# %%
# output
# Out:
# 'depi learning for machine learning depi'

# %%
print("welcome to depi\"machine learning course\"")
# Out:
# welcome to depi"machine learning course"

# %%
print("hello  \t world")
# Out:
# hello  	 world

# %%
x=20
x=2
print(hex(id(x)))
print(hex(id(x)))
# Out:
# 0x7ffb1f47e9d8
# 0x7ffb1f47e9d8

# %%
x=("depi",30,True,{"ml","dl"},10.5)
type(x)
x[1]
# Out:
# 30

# %%
name="rahma"
list(name)
# Out:
# ['r', 'a', 'h', 'm', 'a']
