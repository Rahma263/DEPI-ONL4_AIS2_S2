# %%
name = input("Enter the name:")   # let the user enter the name 
if name[0].lower() == 'r':      # check if the first letter is 'r' or 'R'
    print(f"{name} plays banjo")  
else:
    print(f"{name} does not play banjo")
# Out:
# rahma plays banjo
